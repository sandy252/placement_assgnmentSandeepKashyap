# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('episodes_data.xlsx')

# %%
df.head()
# Out:
#        id                                                url  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type     airdate airtime  runtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00       68
# 1           Chestnut       1       2  regular  2016-10-09   21:00       60
# 2          The Stray       1       3  regular  2016-10-16   21:00       60
# 3  Dissonance Theory       1       4  regular  2016-10-23   21:00       60
# 4        Contrapasso       1       5  regular  2016-10-30   21:00       60
#
#    average rating                                            summary  \
# 0             8.0  A woman named Dolores is a free spirit in the ...
# ...

# %%
df.shape
# Out:
# (36, 13)

# %%
df['name'].value_counts()
# Out:
# The Original                 1
# Chestnut                     1
# Parce Domine                 1
# The Winter Line              1
# The Absence of Field         1
# The Mother of Exiles         1
# Genre                        1
# Decoherence                  1
# Passed Pawn                  1
# Crisis Theory                1
# The Auguries                 1
# Well Enough Alone            1
# Années Folles                1
# Generation Loss              1
# Zhuangzi                     1
# Fidelity                     1
# Metanoia                     1
# The Passenger                1
# Vanishing Point              1
# Kiksuya                      1
# The Well-Tempered Clavier    1
# The Stray                    1
# Dissonance Theory            1
# Contrapasso                  1
# The Adversary                1
# Trompe L'Oeil                1
# Trace Decay                  1
# The Bicameral Mind           1
# Les Écorchés                 1
# Journey Into Night           1
# ...

# %%
df.columns
# Out:
# Index(['id', 'url', 'name', 'season', 'number', 'type', 'airdate', 'airtime',
#        'runtime', 'average rating', 'summary', 'medium image link',
#        'original image link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   36 non-null     int64
#  1   url                  36 non-null     object
#  2   name                 36 non-null     object
#  3   season               36 non-null     int64
#  4   number               36 non-null     int64
#  5   type                 36 non-null     object
#  6   airdate              36 non-null     object
#  7   airtime              36 non-null     object
#  8   runtime              36 non-null     int64
#  9   average rating       36 non-null     float64
#  10  summary              36 non-null     object
#  11  medium image link    36 non-null     object
#  12  original image link  36 non-null     object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 3.8+ KB

# %%
season_one_ratings = d
# Out:
# 1    10
# 2    10
# 3     8
# 4     8
# Name: season, dtype: int64

# %%
season_sum = df.groupby('season')['average rating'].sum()
for season, rating_sum in season_sum.items():
    print(f'Season {season}: {rating_sum}')
# Out:
# Season 1: 80.9
# Season 2: 80.0
# Season 3: 62.2
# Season 4: 60.3

# %%
season_sum.plot(kind='bar', xlabel='season', ylabel='rating_sum', title='Sum of Ratings for Each Season')
# Out:
# <Axes: title={'center': 'Sum of Ratings for Each Season'}, xlabel='season', ylabel='rating_sum'>

# %%
ep_ds = df[['name','average rating','season']]

# %%
ep_ds
# Out:
#                          name  average rating  season
# 0                The Original             8.0       1
# 1                    Chestnut             7.7       1
# 2                   The Stray             7.6       1
# 3           Dissonance Theory             7.9       1
# 4                 Contrapasso             8.0       1
# 5               The Adversary             8.0       1
# 6               Trompe L'Oeil             8.6       1
# 7                 Trace Decay             7.9       1
# 8   The Well-Tempered Clavier             8.5       1
# 9          The Bicameral Mind             8.7       1
# 10         Journey Into Night             7.8       2
# 11                    Reunion             7.7       2
# 12            Virtù e Fortuna             7.7       2
# 13   The Riddle of the Sphinx             8.0       2
# 14               Akane No Mai             7.6       2
# 15                Phase Space             7.7       2
# ...

# %%
ep_ds = ep_ds.groupby('season')

# %%
ep_ds

# %% [markdown]
# ## Question 2

# %% [markdown]
# There is only rating for each each episode and the name of episode is different for each season

# %% [markdown]
# ## Question 3

# %%
d_ds =  df[['name', 'airdate']]
d_ds
# Out:
#                          name     airdate
# 0                The Original  2016-10-02
# 1                    Chestnut  2016-10-09
# 2                   The Stray  2016-10-16
# 3           Dissonance Theory  2016-10-23
# 4                 Contrapasso  2016-10-30
# 5               The Adversary  2016-11-06
# 6               Trompe L'Oeil  2016-11-13
# 7                 Trace Decay  2016-11-20
# 8   The Well-Tempered Clavier  2016-11-27
# 9          The Bicameral Mind  2016-12-04
# 10         Journey Into Night  2018-04-22
# 11                    Reunion  2018-04-29
# 12            Virtù e Fortuna  2018-05-06
# 13   The Riddle of the Sphinx  2018-05-13
# 14               Akane No Mai  2018-05-20
# 15                Phase Space  2018-05-27
# 16               Les Écorchés  2018-06-03
# 17                    Kiksuya  2018-06-10
# 18            Vanishing Point  2018-06-17
# 19              The Passenger  2018-06-24
# 20               Parce Domine  2020-03-15
# ...

# %%
d_ds['airdate'] = pd.to_datetime(d_ds['airdate'])
filtered_df = d_ds[d_ds['airdate'] < '2019-05-01']
names = list(filtered_df['name'].values)
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_28784\3224969616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d_ds['airdate'] = pd.to_datetime(d_ds['airdate'])

# %%
names
# Out:
# ['The Original',
#  'Chestnut',
#  'The Stray',
#  'Dissonance Theory',
#  'Contrapasso',
#  'The Adversary',
#  "Trompe L'Oeil",
#  'Trace Decay',
#  'The Well-Tempered Clavier',
#  'The Bicameral Mind',
#  'Journey Into Night',
#  'Reunion',
#  'Virtù e Fortuna',
#  'The Riddle of the Sphinx',
#  'Akane No Mai',
#  'Phase Space',
#  'Les Écorchés',
#  'Kiksuya',
#  'Vanishing Point',
#  'The Passenger']

# %%
df['average rating'].max()
# Out:
# 8.7

# %% [markdown]
# ## Question 4

# %%
result = df.groupby('season').apply(lambda x: pd.Series({'Highest': x.loc[x['average rating'].idxmax(), 'name'],
                                                         'Lowest': x.loc[x['average rating'].idxmin(), 'name']}))

# %%
result
# Out:
#                    Highest        Lowest
# season
# 1       The Bicameral Mind     The Stray
# 2                  Kiksuya  Akane No Mai
# 3             Parce Domine   Decoherence
# 4                 Zhuangzi  The Auguries

# %% [markdown]
# ## Question 5

# %%
result = df.groupby('season')['average rating'].apply(lambda x: x.value_counts().idxmax())

# %%
result
# Out:
# season
# 1    8.0
# 2    7.7
# 3    8.0
# 4    7.7
# Name: average rating, dtype: float64
