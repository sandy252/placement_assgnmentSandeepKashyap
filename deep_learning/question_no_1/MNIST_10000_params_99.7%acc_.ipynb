# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense
from keras.datasets import mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
# validation_images = train_images[50000:]
# validation_labels = train_labels[50000:]
# train_images = train_images[:50000]
# train_images = train_labels[:50000]

# %%
# train_images.shape
# Out:
# (50000,)

# %%
train_images = train_images.reshape((60000, 28,28,1))

# %%
train_images = train_images.astype('float32')/255

test_images =  test_images.reshape((10000, 28, 28,1))
test_images = test_images.astype('float32')/255

# val_images =  validation_images.reshape((10000, 28, 28,1))
# val_images = validation_images.astype('float32')/255

from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
# val_labels = to_categorical(validation_labels)
test_labels = to_categorical(test_labels)

# %%
val_images = test_images
val_labels = test_labels

# %%
from tensorflow.python.ops.gen_nn_ops import Conv2D
from keras import layers
from keras import models
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense

model = models.Sequential()
model.add(Conv2D(16,(5,5), activation='relu', input_shape = (28,28,1)))
model.add(MaxPool2D(2,2))
model.add(Conv2D(16,(5,5), activation='relu',))
model.add(MaxPool2D(2,2))
model.add(Conv2D(8,(3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(32, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 16)        416
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          6416
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 8)           1160
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 9,378
# Trainable params: 9,378
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'rmsprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy']
              )

# %%
model.fit(train_images, train_labels,validation_data=(val_images, val_labels), epochs = 20, batch_size = 64)
# Out:
# Epoch 1/20
# 938/938 [==============================] - 16s 5ms/step - loss: 0.3721 - accuracy: 0.8867 - val_loss: 0.1472 - val_accuracy: 0.9502
# Epoch 2/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1283 - accuracy: 0.9603 - val_loss: 0.1081 - val_accuracy: 0.9667
# Epoch 3/20
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0848 - accuracy: 0.9739 - val_loss: 0.0721 - val_accuracy: 0.9768
# Epoch 4/20
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0644 - accuracy: 0.9805 - val_loss: 0.0551 - val_accuracy: 0.9825
# Epoch 5/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0538 - accuracy: 0.9835 - val_loss: 0.0500 - val_accuracy: 0.9850
# Epoch 6/20
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0483 - accuracy: 0.9848 - val_loss: 0.0498 - val_accuracy: 0.9848
# Epoch 7/20
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0417 - accuracy: 0.9866 - val_loss: 0.0495 - val_accuracy: 0.9855
# Epoch 8/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0380 - accuracy: 0.9879 - val_loss: 0.0454 - val_accuracy: 0.9848
# Epoch 9/20
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0355 - accuracy: 0.9888 - val_loss: 0.0430 - val_accuracy: 0.9873
# Epoch 10/20
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0327 - accuracy: 0.9897 - val_loss: 0.0465 - val_accuracy: 0.9869
# Epoch 11/20
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0294 - accuracy: 0.9906 - val_loss: 0.0408 - val_accuracy: 0.9880
# Epoch 12/20
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.0406 - val_accuracy: 0.9879
# Epoch 13/20
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0250 - accuracy: 0.9920 - val_loss: 0.0577 - val_accuracy: 0.9840
# Epoch 14/20
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0245 - accuracy: 0.9922 - val_loss: 0.0415 - val_accuracy: 0.9886
# Epoch 15/20
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0219 - accuracy: 0.9930 - val_loss: 0.0842 - val_accuracy: 0.9780
# Epoch 16/20
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 0.0461 - val_accuracy: 0.9881
# Epoch 17/20
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0196 - accuracy: 0.9938 - val_loss: 0.0463 - val_accuracy: 0.9877
# Epoch 18/20
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.0421 - val_accuracy: 0.9894
# Epoch 19/20
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0506 - val_accuracy: 0.9882
# Epoch 20/20
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0496 - val_accuracy: 0.9884

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0449 - accuracy: 0.9876
# [0.04487873613834381, 0.9876000285148621]
