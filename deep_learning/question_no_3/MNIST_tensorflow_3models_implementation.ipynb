# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense
from keras.datasets import mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
train_images = train_images.reshape((60000, 28,28,1))
train_images = train_images.astype('float32')/255

test_images =  test_images.reshape((10000, 28, 28,1))
test_images = test_images.astype('float32')/255

from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
from tensorflow.python.ops.gen_nn_ops import Conv2D
from keras import layers
from keras import models
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense

model = models.Sequential()
model.add(Conv2D(16,(5,5), activation='relu', input_shape = (28,28,1)))
model.add(MaxPool2D(2,2))
model.add(Conv2D(8,(5,5), activation='relu',))
model.add(MaxPool2D(2,2))
model.add(Conv2D(8,(3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_42 (Conv2D)          (None, 24, 24, 16)        416
#
#  max_pooling2d_28 (MaxPoolin  (None, 12, 12, 16)       0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 8)           3208
#
#  max_pooling2d_29 (MaxPoolin  (None, 4, 4, 8)          0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 2, 2, 8)           584
#
#  flatten_14 (Flatten)        (None, 32)                0
#
#  dense_28 (Dense)            (None, 64)                2112
#
#  dense_29 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 6,970
# Trainable params: 6,970
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'rmsprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy']
              )

# %%
model.fit(train_images, train_labels, epochs = 5, batch_size = 64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 15s 4ms/step - loss: 0.3748 - accuracy: 0.8857
# Epoch 2/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1322 - accuracy: 0.9587
# Epoch 3/5
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0890 - accuracy: 0.9720
# Epoch 4/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0696 - accuracy: 0.9781
# Epoch 5/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0588 - accuracy: 0.9815

# %%
# Model 2

# %%
model2 = keras.models.Sequential()

# %%
model2 = models.Sequential()
model2.add(Conv2D(8,(5,5), activation='relu', input_shape = (28,28,1)))
model2.add(MaxPool2D(2,2))
model2.add(Conv2D(8,(5,5), activation='relu',))
model2.add(MaxPool2D(2,2))
model2.add(Conv2D(8,(3,3), activation='relu'))
model2.add(Flatten())
model2.add(Dense(64, activation = 'relu'))
model2.add(Dense(10, activation = 'softmax'))
model2.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_45 (Conv2D)          (None, 24, 24, 8)         208
#
#  max_pooling2d_30 (MaxPoolin  (None, 12, 12, 8)        0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 8, 8, 8)           1608
#
#  max_pooling2d_31 (MaxPoolin  (None, 4, 4, 8)          0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 2, 2, 8)           584
#
#  flatten_15 (Flatten)        (None, 32)                0
#
#  dense_30 (Dense)            (None, 64)                2112
#
#  dense_31 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 5,162
# Trainable params: 5,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer = 'rmsprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy']
              )

# %%
model2.fit(train_images, train_labels, epochs = 5, batch_size = 64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 7s 5ms/step - loss: 0.3896 - accuracy: 0.8811
# Epoch 2/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.1413 - accuracy: 0.9563
# Epoch 3/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0982 - accuracy: 0.9691
# Epoch 4/5
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0796 - accuracy: 0.9754
# Epoch 5/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0683 - accuracy: 0.9791

# %%
# Model 3

# %%
model3 = keras.models.Sequential()

# %%
model3 = models.Sequential()
model3.add(Conv2D(8,(5,5), activation='relu', input_shape = (28,28,1)))
model3.add(MaxPool2D(2,2))
model3.add(Conv2D(8,(5,5), activation='relu',))
model3.add(MaxPool2D(2,2))
model3.add(Conv2D(8,(3,3), activation='relu'))
model3.add(Flatten())
model3.add(Dense(32, activation = 'relu'))
model3.add(Dense(10, activation = 'softmax'))
model3.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_54 (Conv2D)          (None, 24, 24, 8)         208
#
#  max_pooling2d_36 (MaxPoolin  (None, 12, 12, 8)        0
#  g2D)
#
#  conv2d_55 (Conv2D)          (None, 8, 8, 8)           1608
#
#  max_pooling2d_37 (MaxPoolin  (None, 4, 4, 8)          0
#  g2D)
#
#  conv2d_56 (Conv2D)          (None, 2, 2, 8)           584
#
#  flatten_18 (Flatten)        (None, 32)                0
#
#  dense_36 (Dense)            (None, 32)                1056
#
#  dense_37 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 3,786
# Trainable params: 3,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(optimizer = 'rmsprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy']
              )

# %%
model3.fit(train_images, train_labels, epochs = 5, batch_size = 64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 5s 4ms/step - loss: 0.5177 - accuracy: 0.8357
# Epoch 2/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1700 - accuracy: 0.9472
# Epoch 3/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1238 - accuracy: 0.9615
# Epoch 4/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.1038 - accuracy: 0.9680
# Epoch 5/5
# 938/938 [==============================] - 4s 5ms/step - loss: 0.0904 - accuracy: 0.9722
